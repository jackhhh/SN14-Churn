# %%
import ijson
from geopy.distance import geodesic

USER_FILE_URL = "D:/dataset/yelp_academic_dataset_user.json"
REVIEW_FILE_URL = "D:/dataset/yelp_academic_dataset_review.json"
BUSINESS_FILE_URL = "D:/dataset/yelp_academic_dataset_business.json"

# %%
# count the number of active users
def activeUserCount():
    f = open(USER_FILE_URL, encoding="utf-8")
    users = ijson.items(f, "", multiple_values=True)
    active_users = (user for user in users if user["review_count"] >= 50)
    count = 0
    for user in active_users:
        count = count + 1
    print("The total number of active user: " + str(count))
activeUserCount()
# Out:
# The total number of active user: 189978

# %%
# count the number of businesses who have review count >= 1000
def businessCount(lbound: int = 0):
    f = open(BUSINESS_FILE_URL, encoding="utf-8")
    businesses = ijson.items(f, "", multiple_values=True)
    active_businesses = (business for business in businesses if business["review_count"] >= lbound)
    count = 0
    for business in active_businesses:
        count = count + 1
        if count <= 10:
            print(business["business_id"])
    print("The total number of businesses who have review count at least " + str(lbound) + ": " + str(count))
businessCount(1000)
# Out:
# bP6goJODwRnM3AVy45Kn9w
# vecuat0jOia-CJveW3ngDw
# J8Ha6yIvGoU-E31jnCq7Ew
# QdzRS1s0tSltIokm2xV-kA
# 3cLBtLFiH8IRdlEy9S8RiQ
# oug5bLTWP_YTtj1C3_X6Xw
# bZiIIUcpgxh8mpKMDhdqbA
# U9lrX8Nviajz-74dF6zL7g
# Un6u2cECyV4nZb_HGZ-uTA
# PySoEDAeoksJcVCJi8Sjzg
# The total number of businesses who have review count at least 1000: 418

# %%
# count the user who visit business at least n times.
def activeUserCountForBusiness(bid: str, n:int = 2):
    f = open(REVIEW_FILE_URL, encoding="utf-8")
    reviews = ijson.items(f, "", multiple_values=True)
    reviews = (review for review in reviews if review["business_id"] == bid)
    users = {}
    review_count = 0
    for review in reviews:
        review_count = review_count + 1
        user_id = review["user_id"]
        if user_id in users:
            users[user_id] = users[user_id] + 1
        else:
            users[user_id] = 1
    print("The total number of reviews of business " + bid + " : " + str(review_count))
    user_count = 0
    for key in users.keys():
        if users[key] >= n:
            user_count = user_count + 1
    print("The total number of user who visit business " + bid + " at least " + str(n) + " times: " + str(user_count))
activeUserCountForBusiness("bP6goJODwRnM3AVy45Kn9w")
# Out:
# The total number of reviews of business bP6goJODwRnM3AVy45Kn9w : 1031
# The total number of user who visit business bP6goJODwRnM3AVy45Kn9w at least 2 times: 27

# %%
# count the number of business in different cities
def businessCountOfCities():
    f = open(BUSINESS_FILE_URL, encoding="utf-8")
    businesses = ijson.items(f, "", multiple_values=True)
    businesses = (business for business in businesses if business["city"])
    cities = {}
    for business in businesses:
        city = business["city"]
        if city in cities:
            cities[city] = cities[city] + 1
        else:
            cities[city] = 1
    ordered_cities = sorted(cities.items(), key=lambda x:x[1], reverse=True)
    for (key, value) in ordered_cities:
        print(key + ": " + str(value))
businessCountOfCities()
# Out:
# Austin: 22416
# Portland: 18203
# Vancouver: 13330
# Atlanta: 12612
# Orlando: 10637
# Boston: 8263
# Columbus: 6634
# Boulder: 2542
# Cambridge: 2433
# Beaverton: 2252
# Richmond: 1791
# Burnaby: 1725
# Kissimmee: 1713
# Decatur: 1411
# Winter Park: 1288
# vancouver: 1
# Winter Spring: 1
# Cassselberry: 1
# Milwaulkie: 1
# Braintee: 1
# Ocoee Fl: 1
# Perimeter: 1
# Boston-Winthrop: 1
# LAKE CITY: 1
# Clarkson: 1
# Pinehurst: 1
# DUBLIN: 1
# brighton: 1
# Brookline Village: 1
# San dy: 1
# Georgia: 1
# Oakhill: 1
# Fairburn: 1
# Milwuakie: 1
# Lilburn: 1
# Hiliard: 1
# West Roxury: 1
# Arvada: 1
# West Plant: 1
# Marble Cliff: 1
# Merrit Island: 1
# Doctor Phillips: 1
# UPPER ARLNGTN: 1
# CONLEY: 1
# Portland-Eastport Plaza: 1
# DAVENPORT: 1
# Northeast Orlando: 1
# Port coquitlam: 1
# Orlando Fl: 1
# Thoroughbred Estates: 1
# Central: 1
# Charleston: 1
# Dell Valley: 1
# Quincy Center: 1
# South Waltham: 1
# PORTLAND AP: 1
# Altamonte  springs: 1
# Winter Park : 1
# Morgan Hill: 1
# Autin: 1
# Amlin: 1
# Beaverton-Aloha: 1
# Norfolk: 1
# Newton Upper Fall: 1
# Dripping springs: 1
# Vancovuer: 1
# Sand Lake: 1
# Newton Corner: 1
# Downtown Vancouver: 1
# Columbus North: 1
# Kelowna: 1
# Portland Oregon: 1
# Alton: 1
# Delta Park: 1

# %%
# find n business examples in city
def findBusinessExampleInCity(city: str, n: int):
    f = open(BUSINESS_FILE_URL, encoding="utf-8")
    businesses = ijson.items(f, "", multiple_values=True)
    businesses = (business for business in businesses if business["city"] == city)
    for business in businesses:
        print("name: " + business["name"] + " id: " + business["business_id"])
        print("latitude: " + str(business["latitude"]) + " longitude: " + str(business["longitude"]))
        n = n - 1
        if n < 0:
            break
findBusinessExampleInCity("Austin", 10)
# Out:
# name: Lane Wells Jewelry Repair id: N3_Gs3DnX4k9SgpwJxdEfw
# latitude: 30.346169 longitude: -97.711458
# name: Capital City Barber Shop id: tXvdYGvlEceDljN8gt2_3Q
# latitude: 30.1727062 longitude: -97.7999199
# name: DoubleTree by Hilton Hotel Austin id: nTIhpR7MhsALPwg_Hh14EA
# latitude: 30.3263767015 longitude: -97.7045434713
# name: PS Property Management Company id: 8XyEpVdAO0o6iVkVxkWosQ
# latitude: 30.2464652 longitude: -97.7787377
# name: McKinley Chiropractic id: NVfOn7TdnHbaGH97CVB_Qg
# latitude: 30.244902 longitude: -97.857409
# name: El Pollo Rey id: Xw8tuI30T-xihpzwBV-zJg
# latitude: 30.243493 longitude: -97.730141
# name: Austin Regional Clinic: ARC Quarry Lake id: s8eTWEtW5WcnL2kUxrOVmw
# latitude: 30.4016572 longitude: -97.7429434
# name: Eurasia Sushi Bar & Seafood id: NRPemqVb4qpWFF0Avq_6OQ
# latitude: 30.2345329 longitude: -97.8772622
# name: Austin Community College - Rio Grande Campus id: XymxusqpIsZFmN_QNQW_fw
# latitude: 30.2763428964 longitude: -97.7479623166
# name: Texas Global Passport Services id: Nhw7on5kevbomM-GzRXy_A
# latitude: 30.287984 longitude: -97.743246
# name: Wendy's id: bRsDZ44CD3uhGnRY3NeQhQ
# latitude: 30.4418754072 longitude: -97.7465811589

# %%
# find local competitors by distance (distance: km)
def findLocalCompetitors(bid: str, latitude: float, longitude: float, distance: float = 20):
    f = open(BUSINESS_FILE_URL, encoding="utf-8")
    businesses = ijson.items(f, "", multiple_values=True)
    businesses = (business for business in businesses if business["latitude"] and business["longitude"] and business["is_open"] == 1)
    count = 0
    for business in businesses:
        position = (business["latitude"], business["longitude"])
        if geodesic((latitude, longitude), position).km <= distance:
            count = count + 1
            print("name: " + business["name"] + " id: " + business["business_id"])
            print("city: " + business["city"])
    print("number of local competitors around " + str(distance) + "km: " + str(count))
findLocalCompetitors("N3_Gs3DnX4k9SgpwJxdEfw", 30.346169, -97.711458, 1)
# Out:
# name: Lane Wells Jewelry Repair id: N3_Gs3DnX4k9SgpwJxdEfw
# city: Austin
# name: Matt Holm id: 9AQ1io2V6_AXM5Yo_H337A
# city: Austin
# name: Crates On Skates id: ZfKHogPGqQpzgNFSFjfICw
# city: Austin
# name: Texas Tees, Etc id: vctfNR9lnFFHovLtsQKupw
# city: Austin
# name: Legacy Tax Consulting id: rXmI1bUxBJi_mqYRHiLfNw
# city: Austin
# name: Arepas Grill id: PYH2RJzpOnwvqY1IYsIu8A
# city: Austin
# name: Kim Phung Restaurant id: HSpFgxTcf9lihq1R-pcytQ
# city: Austin
# name: Eudaimonia Recovery Homes id: OZX1uBuExwS-stqRPf8DDw
# city: Austin
# name: Lone Star Cab id: T-VFDbG1WXJhGKAB9GYouA
# city: Austin
# name: Holden Roofing id: 5atcNkqLyNGv5tBamuSYEA
# city: Austin
# name: America's Carpet Outlet id: SKRGFfy82Uju2itJoz0WRg
# city: Austin
# name: Long Play Lounge id: 2RQRTGN7EI0MSXPb_auuTw
# city: Austin
# name: Discount Electronics id: z0upGkm6F_fQYtpA1h-x1g
# city: Austin
# name: Austin Pro Siding, Windows & Roofing id: eDAolGfQ3lWkXHICKtKI3A
# city: Austin
# name: Boss Nails id: 63fqU8G2kmGvaFkGNN7w3Q
# city: Austin
# name: E&G Hair Braiding id: 8RcJi9oQNTSMISxtmKHTbw
# city: Austin
# name: Frankenstein Computers id: lCEhbbJ6lo9cat0ywfB0og
# city: Austin
# name: Luxury Auto Works id: Rqb2xN-9HsxyYiWCM62pTQ
# city: Austin
# name: ProReflection id: y5eu17VxlzPZZNNvZa7_vw
# city: Austin
# name: Paradisa Homes id: D2jtXX03k01G6VSghRVB1g
# city: Austin
# name: Hopkins Tax and Consulting id: JSsgGQFBLH02Z8ldDDp-QQ
# city: Austin
# name: Way Construction Services id: icXDDOt_oOVQMX8BaQNSMQ
# city: Austin
# name: Austin Mac Repair id: 1KE6TCtbDnWxXh3mLWrjBQ
# city: Austin
# name: O'Connor Immigration PLLC id: eDwVztSXTpkomrkkGqbIqg
# city: Austin
# name: Waveform Austin id: smOnregoxGuuaFX-fbM8gg
# city: Austin
# name: K&N Service id: 2w793T2zxZwgj0A06-_sIg
# city: Austin
# name: Ink & Toner Station id: uoc3cuhd-Ae_P8-tC_DRzg
# city: Austin
# name: Fruity Mania id: vTWFToT9S_2VIo8ORWYn_Q
# city: Austin
# name: Cristal Jordan - Creative Branding & Business Services id: RsX2ae56Tm1qwuJGgx1Mfg
# city: Austin
# name: Lone Star Filtration id: g9tOCjUJnChOPN5qkb9z7g
# city: Austin
# name: Sunray Waters id: rH2veRD3H4LNXZ9AKPigrA
# city: Austin
# name: Austin's Couch Potatoes Outlet id: y1-2OTMTkOIM6h1xlUYwjA
# city: Austin
# name: A 1 Used Tires id: GUJyJ4z64hiE6Kzgh1EGAg
# city: Austin
# name: King's Hobby id: zwKExesVlEJvoi2ehXOe7A
# city: Austin
# name: Horizen Flooring id: bGDMatNlyS7_hTIrtLC25Q
# city: Austin
# name: Pronto Insurance id: _0RA-KHF2x-hbqZ6AcWpPw
# city: Austin
# name: Ways Insight id: GNMHbgbJAxh8-IcEMm2fYQ
# city: Austin
# name: Sadi's Beauty Works id: Oq3ODuwzBiVJFmEeohdu-A
# city: Austin
# name: Shannon's Personnel Service of Austin id: vDb1jkOk8dCB8PX-d7sWJA
# city: Austin
# name: Law Office of Sade Ogunbode id: NfkC6ykZhayTcV0F8puJEA
# city: Austin
# name: Clear Wireless id: 7Z73HkS9AMGH7boVoHu3Fg
# city: Austin
# name: Hi Tunes Karaoke id: zvv0V00OGoZ9JvMK_9sLsQ
# city: Austin
# name: Tex-Mex Joe's id: d6ZhDsvM86OMGqLTMKuH1Q
# city: Austin
# name: German Auto Center id: NSL5P_5jo4QKL4LAMaWBGw
# city: Austin
# name: Prescription Pest id: 5S72W4o6ZIOzwsDxQZfHbA
# city: Austin
# name: Allstate Insurance: Dana Spruiell id: EPehqDAVfe5e8FwK1QxvWQ
# city: Austin
# name: Pizza Hut id: wnxepgfZtJW2O7YqbIvKiw
# city: Austin
# name: Austin Humane Society id: bBvCneNoDcL2FR4zwDk6Cg
# city: Austin
# name: All Year Heating & Cooling id: MeAXccP9ygvvBFH2IZ0k-A
# city: Austin
# name: Nathaniel Dominguez - The Agency Texas id: Tfi1hPTYuP7k8DfJK0iE0Q
# city: Austin
# name: Hobby Lobby id: PbytXainamOXCm3dina4_g
# city: Austin
# name: Covert Chrysler Dodge Jeep RAM id: TOtXpQU2jihXtYhPz-vWYQ
# city: Austin
# name: Thien Nhon Duong id: MOJ0f9ZHcxCd3Jt4H3sv4g
# city: Austin
# name: ñoños tacos id: knOY5Nt5GlmIxAadPlirvQ
# city: Austin
# name: El Nuevo Mexico- Austin id: CKUn4-PX66Ms8S0FXLYGcw
# city: Austin
# name: Blackerby Violin Shop id: UB0Xo4OiX49lU7JSYws4fw
# city: Austin
# name: Midtown Commons at Crestview Station - Phase I id: sX8ep53TS66H_G0lb_UZRA
# city: Austin
# name: Blue Sky Heating and Air LLC id: uLcBZC1HRCRdcBbpxJzzDA
# city: Austin
# name: LJ Barber Shop id: N1oLffWIEq1CIxssjmrgNw
# city: Austin
# name: 1-800-GOT-JUNK? Austin id: kP2Vs6zex4WW2BA5QYjmhA
# city: Austin
# name: Austin Body Shop id: dUgkF1L0xpSwA7cVRcG4yg
# city: Austin
# name: Aus Tex Restoration id: 5j4LFvHVM3mx5T-qyvVyiw
# city: Austin
# name: Radiante Salon id: vxqrkLgeKw3-pw-FrIiscw
# city: Austin
# name: NTB - National Tire & Battery id: BxOJZxdgJ0IRlu91OROfOg
# city: Austin
# name: The Austin Cell Phone id: THXs-XAFVimruDxPDEWtTg
# city: Austin
# name: Queen Eyebrows Threading id: sfAZGeEC0kcP6b2QxT7VZw
# city: Austin
# name: Cu Members Mortgage id: dSp_ZMhhAiMznQUXoJ-rvQ
# city: Austin
# name: B Vanity Brow & Lash Studio id: N50ZpqV5ZIIZH9WWGgorTQ
# city: Austin
# name: Ranger Motors id: gEWb5AhIbt1aBt907dZBMw
# city: Austin
# name: Continental Collision id: oQAREMHLcoFJfcK3pSfbqg
# city: Austin
# name: Swim School of Austin id: YtVX_YR-RmZqevENqqg7cA
# city: austin
# name: Cash America Pawn id: a4IFF2mR1hInRlvDoq6cAA
# city: Austin
# name: Leading Edge Salon id: DpMJKVl205SEMWjvfwNHaQ
# city: Austin
# name: SERVPRO of Hyde Park/Central Austin id: lQyGBkIi3dJuXNjx4l8WQQ
# city: Austin
# name: Capital Area Counseling id: 6veZoLH6u7qissAfWhQdBQ
# city: Austin
# name: Mc Phail Florist & Greenhouse id: AzMv7_EQD2W6rmtufjiiFw
# city: Austin
# name: Quality Inn & Suites Downtown North id: CIuqJmkmcQKH6LGLnFNO9A
# city: Austin
# name: Archery Country id: 3-LT7GiazrT3HpNdBYkbjA
# city: Austin
# name: Vigilante Gaming Bar id: nfYN65WLXFPTx9e8pSxViA
# city: Austin
# name: Life Storage id: MY443X0PUwuHQfLFgwotOQ
# city: Austin
# name: MoreHands Maid Service id: z_3FOsh-t6jVyd1tm6u2tg
# city: Austin
# name: Scubaland Adventures id: KNFEqn-quryG5lPv396a7A
# city: Austin
# name: Studio Cuts id: UzMNWc-s2yaavLUuDosefA
# city: Austin
# name: Austin Parke Apartments id: mF0yR7MK2BWxDQ9KVUKMDw
# city: Austin
# name: Grande Communications id: vGfUhFGcnoHCS0UwAaM8SA
# city: Austin
# name: Tam Deli & Cafe id: Kk_NDHsv75drldT28_EKaA
# city: Austin
# name: Sovereign Pest Control id: YHV9-p2fgFSvLOhLbtxF-A
# city: Austin
# name: Crestview Commons id: rT4uGDtr0WcwG4ez1hEmSw
# city: Austin
# name: Austin Physical Therapy Specialists id: tMOCmk4Rekp9BdODVumjCQ
# city: Austin
# name: Innovative Water Solutions id: 5f4oEvnAdxVP9Z2CLh3RQQ
# city: Austin
# name: El Pollo Regio id: PLWKRaadW8g1YFUG22_vDw
# city: Austin
# name: Lone Star MTC id: 9NjBNndqe7vwa7nCpcHBCA
# city: Austin
# name: Main Faucet id: KDJkdttziwKQ9OtNML0Vbg
# city: Austin
# name: Daniel's Austin id: GuMZ8tpOrQI6uA-FK9bXQQ
# city: Austin
# name: Maids and Moore id: OuPF15ttUIugTTuwOOkh7Q
# city: Austin
# name: Ed & Sons id: k-SKvaBoBmG1lylwz16Wuw
# city: Austin
# name: Texas Fencing Academy id: SWNrkRSDl5NeHj35YLvJvg
# city: Austin
# name: South Austin Gallery id: xJr9JkShVQtarkdbNd_Hlw
# city: Austin
# name: Andy Howard's Pest Control id: kllP2OedAGEfdwjTSy-LbQ
# city: Austin
# name: Sunsational Solutions id: kkxjXZ3WLea_60MI12fqoQ
# city: Austin
# name: Foot Pain Relief Store id: v7VOYYG72pOd7-dH8OiRvg
# city: Austin
# name: Austin Appliance Techs id: ntTl-UPHVST-8c99AsmwQw
# city: Austin
# name: Chris Gets U Fit id: rfeWE9EDVXFQw95psoNwgw
# city: Austin
# name: RC Health Services Austin id: RpypbBT6FIgfNCHF8djS1w
# city: Austin
# name: Joe's Tree Care id: 0eWbpbZB2arjKj7986S7NA
# city: Austin
# name: A Deal Plumbing id: x1zf1I56sbbTg1BgAnu0IQ
# city: Austin
# name: Game Over Videogames id: gtuFMI5ReEyriLnZ3hzbDw
# city: Austin
# name: Kiwi Services id: S1WynN0XIhc8GK8W_YNtPw
# city: Austin
# name: All Breed Dog Grooming id: pJOfNsbl9Si3FIZUhrUxPA
# city: Austin
# name: Susy Q Cleaning id: ciDsfZTd5128Y6m5dSlIwg
# city: Austin
# name: Public Storage id: OvxrJgwN1UPQmollS0w0Fg
# city: Austin
# name: Top of the Line Detailing id: 8d2Er8ausWsergvlmkaxnQ
# city: Austin
# name: Absolute Auto Glass id: 8-ntBJEzDBvsrCUJ1FHcwg
# city: Austin
# name: Garage Monkeyz id: CC26xAcD9g_ETLSTRJkUhw
# city: Austin
# name: Austin Hardwood Flooring id: bKx-Yc3YHPxrXaV7XWOTiw
# city: Austin
# name: Big Star Bingo id: eiQIdno55c47_M2eO5nihA
# city: Austin
# name: La Gordita Loca id: QKz25cq-ILOOYGOTGi2f9w
# city: Austin
# name: RNR Tire Express id: frZg8o-ZXLouZnVGDway-A
# city: Austin
# name: Ultra Services Remodeling id: BtWv8e6Yk1c6GZtdvaehNA
# city: Austin
# name: Molly Maid of Greater Austin id: wSfcYkxOzO69RnqYpmCKow
# city: Austin
# name: Central Texas Furniture Service id: 1L3Xi_kSvWTqo-OR6fcoVQ
# city: Austin
# name: Top Gunn Equipment Rentals id: ysDMya_3v_oT_Hok7qpMyg
# city: Austin
# name: EFPC, Inc id: 3MmUZGXD8ptGTdJN1FMgEg
# city: Austin
# name: Distinctive Wood Crafts id: SF4S2zXtG4SFhTIAwACejw
# city: Austin
# name: Slavin-Nadal School Of Ballet id: S4nydI15bCa9ETuaEX10FA
# city: Austin
# name: AB Moving - Austin id: vusaGvJz66GNWgaa1lB1vw
# city: Austin
# name: Gethsemane Lutheran Children's Ministry id: Tyx7L0jSDkTrswe33p_eUw
# city: Austin
# name: North Lamar Transit Center id: E4ir5mPiFMb28VgYdYT6RQ
# city: Austin
# name: Josco Supply & Showroom id: kclxV5Keu_P1NUgqrUeNCg
# city: Austin
# name: Happy Clouds Smoke Shop id: 1LmF4hWtGhk_S5iiQHWiVQ
# city: Austin
# name: Coolmasters Air Conditioning & Heating id: feow-Gm2bmGHn2s5Txn0CA
# city: Austin
# name: Phoenix Vapor Shop id: IKc5_joVfuVL-WfYKlFjSg
# city: Austin
# name: Planet Fitness id: y1lHqO7K0bbgLzOhBczSxw
# city: Austin
# name: Fine Wood Repair id: iqtAz6VVKcRYbJigrURzkA
# city: Austin
# name: MSS Contracting id: jBVPKKHxbmEh_MfGiyEJtg
# city: Austin
# name: Carter's Transmission & Auto Service id: GQvc0X3KgIdmft-nFO-7jg
# city: Austin
# name: Adagio Spa id: Njl98S2qWtaWeRNO3HZ02Q
# city: Austin
# name: Austin Tax and Bookkeeping Services id: JBs3YFbQD0fHQYC9Ojq-MA
# city: Austin
# name: Mod Mutt Salon id: bikaRUd79RBZK1bx4E3LOA
# city: Austin
# name: Aptive Environmental id: mOgin8Ab_XgMpGH9ioP8Zw
# city: Austin
# name: In Her Love id: yQyeHAokiuiRvNC65l_1tA
# city: Austin
# name: Gassane Tailors id: lTp-ilFBxkXOZpsCwMyYsQ
# city: Austin
# name: Sos Services-Appliance Division id: 4gKbtSAmQTdDv-fA_5NRHQ
# city: Austin
# name: Luu Auto Repair id: miz7YBTiYoEL2bFx8Z1aeQ
# city: Austin
# name: Brecca Construction id: wDgZGWKDjfGK_UAiJl40Ow
# city: Austin
# name: Josco Plumbing Supply id: V3O7k4JWt73GTwZQYMvbKg
# city: Austin
# name: Toluca Granite id: cTqkyFuUlPqVo9SbAHSzuw
# city: Austin
# name: Guitar Resurrection id: jDlfKAD-g731zbRT_9WYOg
# city: Austin
# name: Bold Electric id: N3ZBTav4zsimWl1xh_KgEQ
# city: Austin
# name: Marios Barber & Ny Style id: LoD9KrQSjoTpw0kA9G4ASw
# city: Austin
# name: Armstrong McCall North Austin id: _2rhMA3-elTvpyWOCy_q9w
# city: Austin
# name: SOHA id: xUtzkHhNH3XCISfzH5mTgQ
# city: Austin
# name: Zoe's Office id: DPIzXuqEYzm3VjvU0NxGaQ
# city: Austin
# name: CW Sewing & Alterations id: NobFBlmit94joUwQpboQiw
# city: Austin
# name: The Atypical Mechanic id: 7g1GYfUOzRNla84s0VnMEw
# city: Austin
# name: Cash Pawn id: 16nZNpFNMx_8Jvec-Ncm4A
# city: Austin
# name: Grainger Industrial Supply id: lF3GIgKV4fJTJ0e7BirshQ
# city: Austin
# name: McKenzie Paul & Associates id: Eekc-LmgugXoLVizP7raSQ
# city: Austin
# name: Petrocelli Services id: XMOrJCHJotZL0Ho_pHCXNA
# city: Austin
# name: Supercuts Training Center id: epehwWewEjWrbP0fapWPGg
# city: Austin
# name: Capitol Saddlery id: YmkgiYXPlLfHG86wjKllRA
# city: Austin
# name: The Austin Stone Counseling Center id: Z1mh4OULik2GWxC-5IGaIA
# city: Austin
# name: Austin Rock Gym id: ZaWi6PkOLWdey8BiUeEl2g
# city: Austin
# name: Novel Escape id: EZ9jzG_cn22kYCqJnGn2Yg
# city: Austin
# name: Quality Living Services id: HxQvO11eIAbRvPuozsi1Fw
# city: Austin
# name: Neptune Society id: 324PtPeyvIVCaWBTiLF9ig
# city: Austin
# name: Nova Body Shop id: BxG25VgIo1RCj6SCG4wFXg
# city: Austin
# name: Second Summer Bride id: WmHxi4rInaTyob1YCgRtNQ
# city: Austin
# name: Girlstart id: SLyjDF_vz5Apt1_GD-TgaQ
# city: Austin
# name: Ryder Truck Rental id: k6moMhNs5tzbkDRdeJuiLQ
# city: Austin
# name: Dean Davis Insurance Agency id: amlsbnseyZb-_k-Ju0ArcA
# city: Austin
# name: Uptown Auto Repair id: 4D1Ymvqt5ihzjcahBRlnAg
# city: Austin
# name: ASG Security id: lCc19uSFlLB1jnHr-XvHNA
# city: Austin
# name: Texas Tech Solutions id: IdKHogtM6_BmdicMteofcA
# city: Austin
# name: The Steamers id: AJxF9yibRmH8yOjlg2ep6A
# city: Austin
# name: Quality Roofing Austin id: g7M5QGbIokU5FZaURrApqg
# city: Austin
# name: Ns Army & Navy Store id: IKX37kHwQ6u3SziDvjMh8g
# city: Austin
# name: Medical Xpress id: muLBzN2kUWWHJSdxSxLoiQ
# city: Austin
# name: Quality Auto Body id: 4PHNgSWiTzVC_yGGJMkCTA
# city: Austin
# name: Clearview Ultrasound id: 53BW46dBH1M5yUfwpREk8w
# city: Austin
# name: David Tucker, CPA id: lszer3SESetuov_AH_QKHw
# city: Austin
# name: E. C. Design Builds Construction id: DIwfnfowdyDQ1My_jDOiAQ
# city: Austin
# name: Barrett's Coffee id: r_lRu79XBGSNSKc0Ix-gdw
# city: Austin
# name: Rent A Car With Cash id: 2YDpp7ovunqrDphoAsdwXw
# city: Austin
# name: Harmony Hypnosis id: vqax1Zeh60ri67vLbizDvQ
# city: Austin
# name: Kas Contracting id: cZVErXA7_YLotHgHh3nmYA
# city: Austin
# name: Red Lobster id: QIcJXY4H22ve9mNDUrG1pg
# city: Austin
# name: Valencia Smiles Dental Care id: KqxgSlM1tAGsUJBQ-c5wKA
# city: Austin
# name: Chago's Caribbean Cuisine id: AqhAJk1OyupIaYjg0JpZlA
# city: Austin
# name: LoLa Beauty id: 3YiOFQfiL_039qJI5m_1zA
# city: Austin
# name: Alterra id: tla1wp17ERZbdUlH4gE52A
# city: Austin
# name: The UPS Store id: 5_fpkMwBHyyFsN4gSTDfnQ
# city: Austin
# name: Green Air Conditioning & Heating id: lCWfZoU8Y3gLIkpLHQM6Rw
# city: Austin
# name: The Joplin at Crestview Apartments id: EUD-D1AgbNnFXOhMzQvMHg
# city: Austin
# name: TYLER'S Outlet id: _BGN-EMkdWog2Dpz_D-o6g
# city: Austin
# name: Austin Blades id: wESWr18QjtnnMuILoMkMkA
# city: Austin
# name: Aimage id: r_uzSjL3Z3gIwRht0EsghQ
# city: Austin
# name: Hertz Rent A Car id: ovt7RUZ4SzAzBHM2d_PQCg
# city: Austin
# name: Powers Family Wellness Center id: nqjOKH4Z14WCxt0wbaYhVw
# city: Austin
# name: Public Storage id: tGw_VSm-ms5gezuUw0fBgw
# city: Austin
# name: Sit Means Sit Dog Training - Austin id: PDEdChjUWHR-SqyhUm_lQw
# city: Austin
# name: Computer NERDZ! id: 9lA3q4BdsA_LM3VgRk3Hew
# city: Austin
# name: 4 Wheel Parts - Off Road Truck & Jeep 4x4 Parts id: qh5f52LsuWTvHu26TLLuJA
# city: Austin
# name: Hall Chiropractic id: jEClzBfgr3eE3NZsVAQ_Kg
# city: Austin
# name: Crossfit Renew id: MMamBIwvPz5MpdPW1OKnhQ
# city: Austin
# name: Fantastic Pool Service id: SNAyIuryUh1q0GOOJTFBiw
# city: Austin
# name: AusTex PCS Cell Repair id: lB1qShPwTC3UXcfD-RnccA
# city: Austin
# number of local competitors around 1km: 207
